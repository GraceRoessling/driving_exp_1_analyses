# %%
import pandas as pd
import numpy as np
import os
import subject
import trial
import piece
from IPython import embed
import dataframe_helper_functions
import preprocess
import statistics
import matplotlib.pyplot as plt
import lane_deviation
import track_piece_correction
import map
# Out:
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# ...
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:22: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[0]] = track_piece_df[track_piece_df.columns[0]].str.replace('(', '')
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\parse_path_center_csv.py:23: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   track_piece_df[track_piece_df.columns[2]] = track_piece_df[track_piece_df.columns[2]].str.replace(')', '')
# ['straight_short', 'right_turn_short_1', 'left_turn_long', 'right_turn_med', 'left_turn_med', 'straight_long', 's_turn_long', 'right_turn_short_2']
# ['straight_short', 'right_turn_short_1', 'left_turn_long', 'right_turn_med', 'left_turn_med', 'straight_long', 's_turn_long', 'right_turn_short_2']

# %%
# Get dictionaries of objects for both groups

subject_dict = preprocess.subject_dict
del subject_dict["wad"]

# %%
# Get dictionary of road center position for lane deviation analysis

master_dict,non_interp_dict = lane_deviation.generate_track_piece_dict(subject_dict)
track_piece_correction.correct_position_for_entire_dataset(subject_dict,master_dict)
# Out:
# C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses\track_piece_correction.py:170: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig1, ax1 = plt.subplots()
