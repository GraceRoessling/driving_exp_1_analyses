# %%
import os
directory_of_python_code = r"C:\Users\graci\Dropbox\PAndA\Thesis Experiment 1\scripts\experiment_analyses"  # Replace with your desired directory
os.chdir(directory_of_python_code)

import execute_pipeline
import pandas as pd
import numpy as np
import os
import subject
import trial
import piece
from IPython import embed
import dataframe_helper_functions
import preprocess
import statistics

# %%
# Get dictionaries of objects for both groups

subject_dict = execute_pipeline.subject_dict

# %%
def entire_trial_metrics(subject, trial_num):
    # get correct trial number for ... info
    total_speed = subject.speed[trial_num]["trial_total"] # total speed
    total_steering = subject.steering[trial_num]["trial_total"] # total steering
    total_lap_time = subject.lap_time[trial_num]["trial_total"] # total lap time
    total_lane_dev = subject.lane_dev[trial_num]["trial_total"] # total lap time
    total_steering_acceleration = subject.steering_acceleration[trial_num]["trial_total"] # total lap time
    
    mean_total_speed = total_speed["mean_speed"] # mean speed
    var_total_speed = total_speed["var_speed"] # var_speed
    
    mean_total_lane_dev = total_lane_dev["mean_lane_dev"] # mean speed
    var_total_lane_dev = total_lane_dev["var_lane_dev"] # var_speed
    
    var_total_steering = total_steering["var_steering"] # var_steering
    mean_total_steering = total_steering["mean_steering"] # var_steering
    
    return(mean_total_speed,var_total_speed,mean_total_lane_dev,var_total_lane_dev,var_total_steering,mean_total_steering,total_lap_time,total_steering_acceleration)

# %%
def low_high_vis_metrics(subject,trial_num):
    print(subject.id)
    print(trial_num)
    track_piece_speed_dict = subject.speed[trial_num]["trial_piece"]
    print(track_piece_speed_dict)
    track_piece_lane_dev_dict = subject.lane_dev[trial_num]["trial_piece"]
    track_piece_steering_dict = subject.steering[trial_num]["trial_piece"]
    track_piece_lap_time_dict = subject.lap_time[trial_num]["trial_piece"]
    track_piece_steering_acceleration_dict = subject.steering_acceleration[trial_num]["trial_piece"]
    
    track_piece_low_vis_lap_time,track_piece_high_vis_lap_time = [],[]
    track_piece_low_vis_steering_acceleration,track_piece_high_vis_steering_acceleration = [],[]

    track_piece_low_vis_mean_speed,track_piece_high_vis_mean_speed = [],[]
    track_piece_low_vis_var_speed,track_piece_high_vis_var_speed = [],[]
    
    track_piece_low_vis_mean_lane_dev,track_piece_high_vis_mean_lane_dev = [],[]
    track_piece_low_vis_var_lane_dev,track_piece_high_vis_var_lane_dev = [],[]
    
    track_piece_low_vis_mean_steering,track_piece_high_vis_mean_steering = [],[]
    track_piece_low_vis_var_steering,track_piece_high_vis_var_steering = [],[]

    # collapse the dictionary into a list
    map = subject.trials[trial_num-1].map
    high_vis,low_vis = map.dict.values()
    print("MAP NUM",map.map_number,"dict values",map.dict.values())

    all_track_pieces = high_vis + low_vis 


    # to compare the two visibility conditions without straight pieces
    #all_track_pieces = [track_piece for track_piece in all_track_pieces if track_piece not in remove_track_piece]
    
    for track_piece in all_track_pieces:
        if track_piece in high_vis:
            track_piece_high_vis_mean_speed.append(track_piece_speed_dict[track_piece]["mean_speed"])
            track_piece_high_vis_var_speed.append(track_piece_speed_dict[track_piece]["var_speed"])
            
            track_piece_high_vis_mean_lane_dev.append(track_piece_lane_dev_dict[track_piece]["mean_lane_dev"])
            track_piece_high_vis_var_lane_dev.append(track_piece_lane_dev_dict[track_piece]["var_lane_dev"])

            track_piece_high_vis_mean_steering.append(track_piece_steering_dict[track_piece]["mean_steering"])
            track_piece_high_vis_var_steering.append(track_piece_steering_dict[track_piece]["var_steering"])

            track_piece_high_vis_lap_time.append(track_piece_lap_time_dict[track_piece]["lap_time"])
            track_piece_high_vis_steering_acceleration.append(track_piece_steering_acceleration_dict[track_piece]["steering_acceleration"])    
            
        elif track_piece in low_vis:
            track_piece_low_vis_mean_speed.append(track_piece_speed_dict[track_piece]["mean_speed"])
            track_piece_low_vis_var_speed.append(track_piece_speed_dict[track_piece]["var_speed"])
            if trial_num == 7: print(track_piece_speed_dict[track_piece])
            track_piece_low_vis_mean_lane_dev.append(track_piece_lane_dev_dict[track_piece]["mean_lane_dev"])
            track_piece_low_vis_var_lane_dev.append(track_piece_lane_dev_dict[track_piece]["var_lane_dev"])
            
            track_piece_low_vis_mean_steering.append(track_piece_steering_dict[track_piece]["mean_steering"])
            track_piece_low_vis_var_steering.append(track_piece_steering_dict[track_piece]["var_steering"])

            track_piece_low_vis_lap_time.append(track_piece_lap_time_dict[track_piece]["lap_time"])
            track_piece_low_vis_steering_acceleration.append(track_piece_steering_acceleration_dict[track_piece]["steering_acceleration"])

    # print("LOW VIS MEAN SPEED",track_piece_low_vis_mean_speed)
    # print("HIGH VIS MEAN SPEED",track_piece_high_vis_mean_speed)
  
    low_vis_mean_speed,high_vis_mean_speed = statistics.mean(track_piece_low_vis_mean_speed),statistics.mean(track_piece_high_vis_mean_speed)
    low_vis_var_speed,high_vis_var_speed = statistics.mean(track_piece_low_vis_var_speed),statistics.mean(track_piece_high_vis_var_speed) 
    
    # print(track_piece_low_vis_mean_lane_dev)
    # print(track_piece_high_vis_mean_lane_dev)
    low_vis_mean_lane_dev,high_vis_mean_lane_dev = statistics.mean(track_piece_low_vis_mean_lane_dev),statistics.mean(track_piece_high_vis_mean_lane_dev)
    low_vis_var_lane_dev,high_vis_var_lane_dev = statistics.mean(track_piece_low_vis_var_lane_dev),statistics.mean(track_piece_high_vis_var_lane_dev) 
    
    low_vis_mean_steering,high_vis_mean_steering = statistics.mean(track_piece_low_vis_mean_steering),statistics.mean(track_piece_high_vis_var_steering)
    low_vis_var_steering,high_vis_var_steering = statistics.mean(track_piece_low_vis_var_steering),statistics.mean(track_piece_high_vis_var_steering)


    low_vis_lap_time,high_vis_lap_time = statistics.mean(track_piece_low_vis_lap_time),statistics.mean(track_piece_high_vis_lap_time)
    low_vis_steering_acceleration,high_vis_steering_acceleration = statistics.mean(track_piece_low_vis_var_speed),statistics.mean(track_piece_high_vis_var_speed) 
    
    variable_collection = { "low_vis" : {"mean_speed": low_vis_mean_speed, "var_speed":low_vis_var_speed,
                                         "mean_lane_dev": low_vis_mean_lane_dev, "var_lane_dev":low_vis_var_lane_dev, 
                                         "mean_steering": low_vis_mean_steering,"var_steering": low_vis_var_steering,
                                         "lap_time": low_vis_lap_time, "steering_acceleration": low_vis_steering_acceleration}, 
                            "high_vis" : {"mean_speed": high_vis_mean_speed, "var_speed":high_vis_var_speed,
                                          "mean_lane_dev": high_vis_mean_lane_dev, "var_lane_dev":high_vis_var_lane_dev, 
                                          "mean_steering": high_vis_mean_steering,"var_steering": high_vis_var_steering,
                                          "lap_time": high_vis_lap_time, "steering_acceleration": high_vis_steering_acceleration}
    }
    
    return(variable_collection)

# %%
def collect_all_ten_trials(subject):
    subject_dict = dict()
    for i in range(0,10):
        trial_num = i+1
        mean_total_speed,var_total_speed,mean_total_lane_dev,var_total_lane_dev,var_total_steering,mean_total_steering,total_lap_time,total_steering_acceleration = entire_trial_metrics(subject, trial_num)
        variable_collection = low_high_vis_metrics(subject,trial_num)
        subject_dict[trial_num] = { "condition" : subject.condition,
                                    "Trial_Total" : {"mean_total_speed":mean_total_speed, "var_total_speed": var_total_speed,
                                                            "mean_total_lane_dev":mean_total_lane_dev, "var_total_lane_dev": var_total_lane_dev,
                                                            "mean_total_steering":mean_total_steering,"var_total_steering":var_total_steering,"total_lap_time": total_lap_time,"total_steering_acceleration": total_steering_acceleration
                                                    },
                                    "Trial_Piece" : {"high_vis": {"mean_speed":variable_collection["high_vis"]["mean_speed"], "var_speed":variable_collection["high_vis"]["var_speed"],
                                                                  "mean_lane_dev":variable_collection["high_vis"]["mean_lane_dev"], "var_lane_dev":variable_collection["high_vis"]["var_lane_dev"],
                                                                  "mean_steering":variable_collection["high_vis"]["mean_steering"],"var_steering":variable_collection["high_vis"]["var_steering"],
                                                                  "lap_time":variable_collection["high_vis"]["lap_time"], "steering_acceleration":variable_collection["high_vis"]["steering_acceleration"]
                                                                  },
                                                     "low_vis" : {"mean_speed":variable_collection["low_vis"]["mean_speed"], "var_speed":variable_collection["low_vis"]["var_speed"] ,
                                                                   "mean_lane_dev":variable_collection["low_vis"]["mean_lane_dev"], "var_lane_dev":variable_collection["low_vis"]["var_lane_dev"] ,
                                                                   "mean_steering":variable_collection["low_vis"]["mean_steering"],"var_steering":variable_collection["low_vis"]["var_steering"],
                                                                   "lap_time":variable_collection["low_vis"]["lap_time"], "steering_acceleration":variable_collection["low_vis"]["steering_acceleration"]}
                                                    }
                                  }
    return(subject_dict)

# %%
# Create dictionary to collect info across all ten trials
master_dict = dict() # contains data for all subjects!\

#Test case
subject_id = "guy"
subj = subject_dict[subject_id] #identify subject
subject_data_dict = collect_all_ten_trials(subj)
master_dict[subject_id] = subject_data_dict

# Entire dataset
# for subject_id in subject_dict:
#     subj = subject_dict[subject_id] #identify subject
#     subject_data_dict = collect_all_ten_trials(subj)
#     master_dict[subject_id] = subject_data_dict
# Out:
# guy
# 1
# {'long_straight': {'mean_speed': 8.684619211573237, 'var_speed': 29.727761124091188, 'sd_speed': 5.452317041780603}, 'zig_zag': {'mean_speed': 17.998468012775017, 'var_speed': 10.346908967596333, 'sd_speed': 3.2166611521259636}, 'short_straight_1': {'mean_speed': 26.532420449438202, 'var_speed': 0.16098150923615942, 'sd_speed': 0.4012250107310852}, 'u_turn': {'mean_speed': 24.465703704581358, 'var_speed': 7.531568374075832, 'sd_speed': 2.7443703055666218}, 'short_straight_2': {'mean_speed': 26.203376923076924, 'var_speed': 1.4520418031526496, 'sd_speed': 1.205006972242339}, 'turn_4': {'mean_speed': 16.918482079831932, 'var_speed': 18.175417470597978, 'sd_speed': 4.2632637111253135}, 'short_straight_3': {'mean_speed': 25.224882857142852, 'var_speed': 0.31588977167396853, 'sd_speed': 0.5620407206546235}, 'y_turn': {'mean_speed': 19.43739911908646, 'var_speed': 25.360953983346935, 'sd_speed': 5.035966042711858}, 'short_straight_4': {'mean_speed': 25.643420113636363, 'var_speed': 0.2614233201988375, 'sd_speed': 0.5112957267558937}, 'turn_1': {'mean_speed': 21.670399200819674, 'var_speed': 7.969885919972873, 'sd_speed': 2.8230986380168996}, 'short_straight_5': {'mean_speed': 23.383467575757578, 'var_speed': 0.7152526584042667, 'sd_speed': 0.8457261131147995}, 'lane_convergence': {'mean_speed': 26.71311131004367, 'var_speed': 0.927049886841259, 'sd_speed': 0.9628342987457702}, 'short_straight_6': {'mean_speed': 28.410334390243904, 'var_speed': 0.028046735982956972, 'sd_speed': 0.16747159754106655}, 'turn_2': {'mean_speed': 22.254096940639272, 'var_speed': 10.838215806349886, 'sd_speed': 3.292144560366371}, 'short_straight_7': {'mean_speed': 24.99381451923077, 'var_speed': 0.2258433962696698, 'sd_speed': 0.47522983520573475}, 'turn_3': {'mean_speed': 18.70899430523918, 'var_speed': 12.288959999777997, 'sd_speed': 3.505561295966453}, 'short_straight_8': {'mean_speed': 24.97599215686275, 'var_speed': 0.43836636278540075, 'sd_speed': 0.6620924125719919}}
# MAP NUM 1 dict values dict_values([['long_straight', 'short_straight_1', 'u_turn', 'short_straight_2', 'turn_4', 'short_straight_3', 'y_turn', 'short_straight_4', 'turn_1', 'short_straight_5', 'lane_convergence', 'short_straight_6', 'turn_2', 'short_straight_7', 'turn_3', 'short_straight_8'], ['zig_zag']])
# guy
# 2
# {'long_straight': {'mean_speed': 12.593530362282879, 'var_speed': 50.4903229155724, 'sd_speed': 7.10565429187013}, 'turn_2': {'mean_speed': 19.23005724137931, 'var_speed': 3.2180005221638637, 'sd_speed': 1.7938786252597647}, 'short_straight_1': {'mean_speed': 23.260205619834714, 'var_speed': 0.42794624424148753, 'sd_speed': 0.654176004024519}, 'turn_3': {'mean_speed': 15.871100976645435, 'var_speed': 22.682890080685272, 'sd_speed': 4.762655780201344}, 'short_straight_2': {'mean_speed': 25.051693304347822, 'var_speed': 0.45053370708021373, 'sd_speed': 0.6712180771405175}, 'turn_4': {'mean_speed': 19.449830519801978, 'var_speed': 11.202115091852086, 'sd_speed': 3.3469560935052742}, 'short_straight_3': {'mean_speed': 22.19641449541285, 'var_speed': 1.200272149928678, 'sd_speed': 1.0955693268473146}, 'zig_zag': {'mean_speed': 19.622359958779885, 'var_speed': 17.036823782407012, 'sd_speed': 4.127568749567597}, 'short_straight_4': {'mean_speed': 24.00270584070796, 'var_speed': 1.9507582074352243, 'sd_speed': 1.396695459803326}, 'large_horseshoe': {'mean_speed': 21.30378487474611, 'var_speed': 9.616639442534622, 'sd_speed': 3.101070692927625}, 'short_straight_5': {'mean_speed': 22.48034219512195, 'var_speed': 1.4234039760107162, 'sd_speed': 1.1930649504577344}, 'y_turn': {'mean_speed': 19.229565008726002, 'var_speed': 18.822715474272247, 'sd_speed': 4.338515353697881}, 'short_straight_6': {'mean_speed': 25.33428326732673, 'var_speed': 0.3708534118622179, 'sd_speed': 0.6089773492193432}, 'lane_convergence': {'mean_speed': 27.23402155339806, 'var_speed': 0.40351648258294115, 'sd_speed': 0.6352294723821788}, 'short_straight_7': {'mean_speed': 28.411904777777778, 'var_speed': 0.044625214454444354, 'sd_speed': 0.21124680933553613}, 'turn_1': {'mean_speed': 21.298294599156122, 'var_speed': 12.550828070932713, 'sd_speed': 3.5427147882566996}, 'short_straight_8': {'mean_speed': 26.240161443298973, 'var_speed': 0.22237306048122865, 'sd_speed': 0.4715644817850775}}
# MAP NUM 5 dict values dict_values([['long_straight', 'turn_2', 'short_straight_1', 'turn_3', 'short_straight_2', 'short_straight_3', 'zig_zag', 'short_straight_4', 'large_horseshoe', 'short_straight_5', 'y_turn', 'short_straight_6', 'lane_convergence', 'short_straight_7', 'turn_1', 'short_straight_8'], ['turn_4']])
# guy
# 3
# {'long_straight': {'mean_speed': 13.056648902050116, 'var_speed': 52.94484241373137, 'sd_speed': 7.276320664575701}, 'turn_2': {'mean_speed': 21.78415693617022, 'var_speed': 4.696779165972256, 'sd_speed': 2.167205381585293}, 'short_straight_1': {'mean_speed': 26.413834090909088, 'var_speed': 0.07125040363134795, 'sd_speed': 0.26692771237049917}, 'u_turn': {'mean_speed': 23.123136298882677, 'var_speed': 1.9115984098583105, 'sd_speed': 1.3826056595639664}, 'short_straight_2': {'mean_speed': 26.698061727272727, 'var_speed': 0.22217430202175972, 'sd_speed': 0.4713536910025843}, 'turn_1': {'mean_speed': 22.520927590361445, 'var_speed': 9.068264356881908, 'sd_speed': 3.0113559000692542}, 'short_straight_3': {'mean_speed': 26.34048239316239, 'var_speed': 0.18332176968215436, 'sd_speed': 0.4281609156405502}, 'small_horseshoe': {'mean_speed': 23.56379069456067, 'var_speed': 3.970238709773638, 'sd_speed': 1.992545786117257}, 'short_straight_4': {'mean_speed': 24.613875190839693, 'var_speed': 0.8191691134590019, 'sd_speed': 0.9050796171934279}, 'lane_convergence': {'mean_speed': 27.540414892703865, 'var_speed': 0.5379780727104411, 'sd_speed': 0.733469885346659}, 'short_straight_5': {'mean_speed': 28.801466226415098, 'var_speed': 0.013959921136100667, 'sd_speed': 0.11815211016355429}, 'turn_3': {'mean_speed': 19.644440453563714, 'var_speed': 19.329857972061046, 'sd_speed': 4.396573435308575}, 'short_straight_6': {'mean_speed': 25.292968103448274, 'var_speed': 0.497054896358111, 'sd_speed': 0.7050212027720237}, 'y_turn': {'mean_speed': 20.566320841269842, 'var_speed': 23.538028588456683, 'sd_speed': 4.85160062128538}, 'short_straight_7': {'mean_speed': 25.89323060869565, 'var_speed': 0.21550106114962647, 'sd_speed': 0.4642209184748426}, 'turn_5': {'mean_speed': 16.705623711111112, 'var_speed': 28.31427215768676, 'sd_speed': 5.321115687305319}, 'short_straight_8': {'mean_speed': 25.733325275590555, 'var_speed': 0.4883971678155981, 'sd_speed': 0.6988541820835003}}
# MAP NUM 8 dict values dict_values([['long_straight', 'short_straight_1', 'u_turn', 'short_straight_2', 'turn_1', 'short_straight_3', 'small_horseshoe', 'short_straight_4', 'lane_convergence', 'short_straight_5', 'turn_3', 'short_straight_6', 'y_turn', 'short_straight_7', 'turn_5', 'short_straight_8'], ['turn_2']])
# guy
# 4
# {'long_straight': {'mean_speed': 10.250656454198472, 'var_speed': 23.17623800597894, 'sd_speed': 4.814170541846118}, 'large_horseshoe': {'mean_speed': 20.230513675263776, 'var_speed': 7.432548269826074, 'sd_speed': 2.7262700287803616}, 'short_straight_1': {'mean_speed': 22.394682056737587, 'var_speed': 0.8535341858878823, 'sd_speed': 0.9238691389411611}, 'u_turn': {'mean_speed': 18.59067350540216, 'var_speed': 0.909714118344909, 'sd_speed': 0.9537893469445489}, 'short_straight_2': {'mean_speed': 21.617994726027398, 'var_speed': 0.3100819388540623, 'sd_speed': 0.5568500146844412}, 'turn_4': {'mean_speed': 15.892766283367557, 'var_speed': 15.028604420675666, 'sd_speed': 3.876674402200379}, 'short_straight_3': {'mean_speed': 24.84840583333333, 'var_speed': 0.7850399680015903, 'sd_speed': 0.8860248122945487}, 'y_turn': {'mean_speed': 19.760823170320403, 'var_speed': 24.260276820913585, 'sd_speed': 4.925472243441596}, 'short_straight_4': {'mean_speed': 25.63633808333333, 'var_speed': 0.1894877312593208, 'sd_speed': 0.435301885200743}, 'turn_3': {'mean_speed': 18.75972131403118, 'var_speed': 16.307835553139565, 'sd_speed': 4.03829612004117}, 'short_straight_5': {'mean_speed': 25.93209552845528, 'var_speed': 0.43162654750525137, 'sd_speed': 0.6569829126432828}, 'lane_convergence': {'mean_speed': 28.010215097087382, 'var_speed': 0.27577387662218567, 'sd_speed': 0.5251417681180822}, 'short_straight_6': {'mean_speed': 29.034367037037033, 'var_speed': 0.017683915280858463, 'sd_speed': 0.1329808831406171}, 'turn_2': {'mean_speed': 22.55263611713666, 'var_speed': 13.332683628107281, 'sd_speed': 3.651394751065308}, 'short_straight_7': {'mean_speed': 25.348966803278685, 'var_speed': 0.5364784944979608, 'sd_speed': 0.7324469226489799}, 'turn_1': {'mean_speed': 23.58981164251208, 'var_speed': 1.1335741398278043, 'sd_speed': 1.0646943879948858}, 'short_straight_8': {'mean_speed': 26.02471009433962, 'var_speed': 0.296307799059991, 'sd_speed': 0.5443416198124033}}
# MAP NUM 2 dict values dict_values([['long_straight', 'large_horseshoe', 'short_straight_1', 'short_straight_2', 'turn_4', 'short_straight_3', 'y_turn', 'short_straight_4', 'turn_3', 'short_straight_5', 'lane_convergence', 'short_straight_6', 'turn_2', 'short_straight_7', 'turn_1', 'short_straight_8'], ['u_turn']])
# guy
# 5
# {'long_straight': {'mean_speed': 15.759069322490708, 'var_speed': 79.23481457524116, 'sd_speed': 8.901393968095174}, 'turn_3': {'mean_speed': 20.045057706422018, 'var_speed': 3.682905434707831, 'sd_speed': 1.919089741181436}, 'short_straight_1': {'mean_speed': 23.2971004964539, 'var_speed': 1.4887323403590373, 'sd_speed': 1.220136197462823}, 'y_turn': {'mean_speed': 22.919255850860417, 'var_speed': 3.2460012049415643, 'sd_speed': 1.8016662301718274}, 'short_straight_2': {'mean_speed': 26.728261636363634, 'var_speed': 0.21518210956610503, 'sd_speed': 0.4638772570045928}, 'lane_convergence': {'mean_speed': 27.100903083333332, 'var_speed': 4.118239676633131, 'sd_speed': 2.029344642152518}, 'short_straight_3': {'mean_speed': 0.00018526984126984128, 'var_speed': 1.7989616518177163e-06, 'sd_speed': 0.0013412537611569692}, 'turn_4': {'mean_speed': 23.451846246153845, 'var_speed': 11.127654210039507, 'sd_speed': 3.335813875209393}, 'short_straight_4': {'mean_speed': 2.4361356499999998, 'var_speed': 0.6579029179004346, 'sd_speed': 0.8111121487811871}, 'small_horseshoe': {'mean_speed': 22.31472694326842, 'var_speed': 9.997431113291073, 'sd_speed': 3.161871457426926}, 'short_straight_5': {'mean_speed': 22.516087092198582, 'var_speed': 1.3209435025550558, 'sd_speed': 1.1493230627439162}, 'turn_1': {'mean_speed': 22.294295675105484, 'var_speed': 5.273921265858423, 'sd_speed': 2.296501962955491}, 'short_straight_6': {'mean_speed': 23.413320661764708, 'var_speed': 1.2949108751869662, 'sd_speed': 1.1379415078056367}, 'turn_2': {'mean_speed': 18.789424133064514, 'var_speed': 18.21457881179965, 'sd_speed': 4.267854122600683}, 'short_straight_7': {'mean_speed': 25.59511430894309, 'var_speed': 0.8418837786657071, 'sd_speed': 0.9175422489813246}, 'zig_zag': {'mean_speed': 21.501031755407652, 'var_speed': 19.422539695003824, 'sd_speed': 4.4071010534141175}, 'short_straight_8': {'mean_speed': 26.47387700854701, 'var_speed': 0.28852084288838803, 'sd_speed': 0.5371413621090709}}
# MAP NUM 6 dict values dict_values([['long_straight', 'turn_3', 'short_straight_1', 'y_turn', 'short_straight_2', 'lane_convergence', 'short_straight_3', 'turn_4', 'short_straight_4', 'short_straight_5', 'turn_1', 'short_straight_6', 'turn_2', 'short_straight_7', 'zig_zag', 'short_straight_8'], ['small_horseshoe']])
# guy
# 6
# {'long_straight': {'mean_speed': 13.718390084699452, 'var_speed': 49.236776035073376, 'sd_speed': 7.0168921920657565}, 'turn_3': {'mean_speed': 19.821871920289855, 'var_speed': 7.330220070296791, 'sd_speed': 2.707437916240517}, 'short_straight_1': {'mean_speed': 22.477370916666665, 'var_speed': 1.3831809008319262, 'sd_speed': 1.1760871144740623}, 'lane_convergence': {'mean_speed': 25.09440688888889, 'var_speed': 0.288576228208135, 'sd_speed': 0.5371929152624176}, 'short_straight_2': {'mean_speed': 24.592744271844662, 'var_speed': 0.908848772169807, 'sd_speed': 0.9533356031166605}, 'large_horseshoe': {'mean_speed': 22.9864470389049, 'var_speed': 9.337366104316605, 'sd_speed': 3.0557104091056475}, 'short_straight_3': {'mean_speed': 22.349236589147285, 'var_speed': 1.6163423045663998, 'sd_speed': 1.2713545156904111}, 'y_turn': {'mean_speed': 20.09277446096654, 'var_speed': 14.907998770283601, 'sd_speed': 3.8610877703418764}, 'short_straight_4': {'mean_speed': 25.666482523364486, 'var_speed': 0.3585415949699877, 'sd_speed': 0.5987834291043697}, 'turn_2': {'mean_speed': 20.54345073319756, 'var_speed': 11.190134324803951, 'sd_speed': 3.345165814246575}, 'short_straight_5': {'mean_speed': 25.99507310679612, 'var_speed': 0.2841027201333904, 'sd_speed': 0.5330128705138276}, 'zig_zag': {'mean_speed': 20.324364051063828, 'var_speed': 15.618036799974204, 'sd_speed': 3.951966194184131}, 'short_straight_6': {'mean_speed': 26.1605087, 'var_speed': 0.36542688218112107, 'sd_speed': 0.6045054856501478}, 'short_straight_7': {'mean_speed': 24.81553504201681, 'var_speed': 0.5396847732591081, 'sd_speed': 0.734632406894161}, 'turn_4': {'mean_speed': 17.342516170212765, 'var_speed': 15.43923614012179, 'sd_speed': 3.9292793410652025}, 'short_straight_8': {'mean_speed': 25.149575892857143, 'var_speed': 0.5144884360172137, 'sd_speed': 0.7172784926492733}}
# MAP NUM 7 dict values dict_values([['long_straight', 'turn_3', 'short_straight_1', 'lane_convergence', 'short_straight_2', 'large_horseshoe', 'short_straight_3', 'y_turn', 'short_straight_4', 'turn_2', 'short_straight_5', 'turn_3', 'short_straight_6', 'turn_4', 'short_straight_7', 'short_straight_8'], ['zig_zag']])
# guy
# 7
# {'long_straight': {'mean_speed': 13.740379956120094, 'var_speed': 59.170699365870526, 'sd_speed': 7.6922493047138385}, 'turn_1': {'mean_speed': 23.197062397260275, 'var_speed': 11.324219088790814, 'sd_speed': 3.36514770683113}, 'short_straight_1': {'mean_speed': 21.72324710578842, 'var_speed': 9.768531392009807, 'sd_speed': 3.125464988127336}, 'y_turn': {'mean_speed': 22.698254776119402, 'var_speed': 2.4050907515258895, 'sd_speed': 1.550835501117346}, 'short_straight_2': {'mean_speed': 14.859132873646208, 'var_speed': 11.47199388754067, 'sd_speed': 3.387033198470406}, 'small_horseshoe': {'mean_speed': 21.90638564102564, 'var_speed': 8.28525745429213, 'sd_speed': 2.8784123148520835}, 'short_straight_3': {'mean_speed': 24.236490645161293, 'var_speed': 0.8496150761963287, 'sd_speed': 0.9217456678478769}, 'u_turn': {'mean_speed': 23.355371202346042, 'var_speed': 10.525795589274027, 'sd_speed': 3.2443482533898895}, 'short_straight_4': {'mean_speed': 28.259616605504586, 'var_speed': 0.06260384645040769, 'sd_speed': 0.25020760669973185}, 'turn_3': {'mean_speed': 18.896874451901564, 'var_speed': 15.530687413334617, 'sd_speed': 3.9408993153003307}, 'short_straight_5': {'mean_speed': 24.407736569343065, 'var_speed': 1.594185708907997, 'sd_speed': 1.2626106719444425}, 'lane_convergence': {'mean_speed': 28.27284795454546, 'var_speed': 0.23956545890675596, 'sd_speed': 0.48945424597888204}, 'short_straight_6': {'mean_speed': 26.409507833333336, 'var_speed': 0.3086618476473671, 'sd_speed': 0.5555734403725282}, 'turn_4': {'mean_speed': 19.65071151807229, 'var_speed': 13.85365536614141, 'sd_speed': 3.7220498876481236}, 'short_straight_7': {'mean_speed': 28.04828924528302, 'var_speed': 0.8015997278203773, 'sd_speed': 0.8953210194228532}}
# MAP NUM 4 dict values dict_values([['long_straight', 'turn_1', 'short_straight_1', 'short_straight_2', 'small_horseshoe', 'short_straight_3', 'u_turn', 'short_straight_4', 'turn_1', 'short_straight_5', 'turn_3', 'short_straight_6', 'lane_convergence', 'short_straight_7', 'turn_4', 'short_straight_8'], ['y_turn']])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 7
#       5 subject_id = "guy"
#       6 subj = subject_dict[subject_id] #identify subject
# ----> 7 subject_data_dict = collect_all_ten_trials(subj)
#       8 master_dict[subject_id] = subject_data_dict
#      10 # Entire dataset
#      11 # for subject_id in subject_dict:
#      12 #     subj = subject_dict[subject_id] #identify subject
#      13 #     subject_data_dict = collect_all_ten_trials(subj)
#      14 #     master_dict[subject_id] = subject_data_dict
#
# Cell In[5], line 6, in collect_all_ten_trials(subject)
#       4     trial_num = i+1
#       5     mean_total_speed,var_total_speed,mean_total_lane_dev,var_total_lane_dev,var_total_steering,mean_total_steering,total_lap_time,total_steering_acceleration = entire_trial_metrics(subject, trial_num)
# ----> 6     variable_collection = low_high_vis_metrics(subject,trial_num)
#       7     subject_dict[trial_num] = { "condition" : subject.condition,
#       8                                 "Trial_Total" : {"mean_total_speed":mean_total_speed, "var_total_speed": var_total_speed,
#       9                                                         "mean_total_lane_dev":mean_total_lane_dev, "var_total_lane_dev": var_total_lane_dev,
#    (...)
#      21                                                 }
#      22                               }
#      23 return(subject_dict)
#
# Cell In[12], line 36, in low_high_vis_metrics(subject, trial_num)
#      34 for track_piece in all_track_pieces:
#      35     if track_piece in high_vis:
# ---> 36         track_piece_high_vis_mean_speed.append(track_piece_speed_dict[track_piece]["mean_speed"])
#      37         track_piece_high_vis_var_speed.append(track_piece_speed_dict[track_piece]["var_speed"])
#      39         track_piece_high_vis_mean_lane_dev.append(track_piece_lane_dev_dict[track_piece]["mean_lane_dev"])
#
# KeyError: 'short_straight_8'

# %%
# Fetch data to examine steering angle -- why is it wack?

subject_id = "boss"

# %%
master_df = {}

for subject_id in subject_dict:
    subj = subject_dict[subject_id] #identify subject
    # manually added (not trial specific)
    master_df['subject_id'] = subj.id
    master_df['condition'] = subj.condition
        
    for i in range(0,10):
        trial_num = i+1
        master_df[f'mean_total_speed_{trial_num}'] = master_dict[subject_id][trial_num]['Trial_Total']["mean_total_speed"]
        master_df[f'var_total_speed_{trial_num}'] = master_dict[subject_id][trial_num]['Trial_Total']["var_total_speed"]
            
        master_df[f'mean_total_lane_dev_{trial_num}'] = master_dict[subject_id][trial_num]['Trial_Total']["mean_total_lane_dev"]
        master_df[f'var_total_lane_dev_{trial_num}'] = master_dict[subject_id][trial_num]['Trial_Total']["var_total_lane_dev"]
        
        master_df[f'mean_total_steering_{trial_num}'] = master_dict[subject_id][trial_num]['Trial_Total']["mean_total_steering"]
        master_df[f'var_total_steering_{trial_num}'] = master_dict[subject_id][trial_num]['Trial_Total']["var_total_steering"]

        master_df[f'total_lap_time_{trial_num}'] = master_dict[subject_id][trial_num]['Trial_Total']["total_lap_time"]
        master_df[f'total_steering_acceleration_{trial_num}'] = master_dict[subject_id][trial_num]['Trial_Total']["total_steering_acceleration"]

        master_df[f'high_vis_mean_speed_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["high_vis"]["mean_speed"]
        master_df[f'high_vis_var_speed_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["high_vis"]["var_speed"]
        master_df[f'high_vis_mean_lane_dev_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["high_vis"]["mean_lane_dev"]
        master_df[f'high_vis_var_lane_dev_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["high_vis"]["var_lane_dev"]
        master_df[f'high_vis_mean_steering_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["high_vis"]["mean_steering"]
        master_df[f'high_vis_var_steering_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["high_vis"]["var_steering"]
        master_df[f'high_vis_lap_time_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["high_vis"]["lap_time"]
        master_df[f'high_vis_steering_acceleration_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["high_vis"]["steering_acceleration"]

        master_df[f'low_vis_mean_speed_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["low_vis"]["mean_speed"]
        master_df[f'low_vis_var_speed_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["low_vis"]["var_speed"]
        master_df[f'low_vis_mean_lane_dev_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["low_vis"]["mean_lane_dev"]
        master_df[f'low_vis_var_lane_dev_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["low_vis"]["var_lane_dev"]
        master_df[f'low_vis_mean_steering_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["low_vis"]["mean_steering"]
        master_df[f'low_vis_var_steering_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["low_vis"]["var_steering"]
        master_df[f'low_vis_lap_time_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["low_vis"]["lap_time"]
        master_df[f'low_vis_steering_acceleration_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["low_vis"]["steering_acceleration"]

# %%
# Define the list of column names
columns = [
    'subject_id', 'condition',
    *[f'mean_total_speed_{i}' for i in range(1, 11)],
    *[f'var_total_speed_{i}' for i in range(1, 11)],
    *[f'mean_total_lane_dev_{i}' for i in range(1, 11)],
    *[f'var_total_lane_dev_{i}' for i in range(1, 11)],
    *[f'mean_total_steering_{i}' for i in range(1, 11)],
    *[f'var_total_steering_{i}' for i in range(1, 11)],
    *[f'total_lap_time_{i}' for i in range(1, 11)],
    *[f'total_steering_acceleration_{i}' for i in range(1, 11)],
    *[f'high_vis_mean_speed_{i}' for i in range(1, 11)],
    *[f'high_vis_var_speed_{i}' for i in range(1, 11)],
    *[f'high_vis_mean_lane_dev_{i}' for i in range(1, 11)],
    *[f'high_vis_var_lane_dev_{i}' for i in range(1, 11)],
    *[f'high_vis_mean_steering_{i}' for i in range(1, 11)],
    *[f'high_vis_var_steering_{i}' for i in range(1, 11)],
    *[f'high_vis_lap_time_{i}' for i in range(1, 11)],
    *[f'high_vis_steering_acceleration_{i}' for i in range(1, 11)],
    *[f'low_vis_mean_speed_{i}' for i in range(1, 11)],
    *[f'low_vis_var_speed_{i}' for i in range(1, 11)],
    *[f'low_vis_mean_lane_dev_{i}' for i in range(1, 11)],
    *[f'low_vis_var_lane_dev_{i}' for i in range(1, 11)],
    *[f'low_vis_mean_steering_{i}' for i in range(1, 11)],
    *[f'low_vis_var_steering_{i}' for i in range(1, 11)],
    *[f'low_vis_lap_time_{i}' for i in range(1, 11)],
    *[f'low_vis_steering_acceleration_{i}' for i in range(1, 11)],
]

# Create an empty DataFrame with the desired columns
master_df = pd.DataFrame(columns=columns)

# Iterate through the subjects and populate the rows
for subject_id in subject_dict:

    subj = subject_dict[subject_id]  # identify subject
    row_data = {'subject_id': subj.id, 'condition': subj.condition}  # initialize row data

    for i in range(0, 10):
        trial_num = i + 1
        row_data[f'mean_total_speed_{trial_num}'] = master_dict[subject_id][trial_num]['Trial_Total']["mean_total_speed"]
        row_data[f'var_total_speed_{trial_num}'] = master_dict[subject_id][trial_num]['Trial_Total']["var_total_speed"]
        row_data[f'mean_total_lane_dev_{trial_num}'] = master_dict[subject_id][trial_num]['Trial_Total']["mean_total_lane_dev"]
        row_data[f'var_total_lane_dev_{trial_num}'] = master_dict[subject_id][trial_num]['Trial_Total']["var_total_lane_dev"]
        row_data[f'mean_total_steering_{trial_num}'] = master_dict[subject_id][trial_num]['Trial_Total']["mean_total_steering"]
        row_data[f'var_total_steering_{trial_num}'] = master_dict[subject_id][trial_num]['Trial_Total']["var_total_steering"]
        row_data[f'total_lap_time_{trial_num}'] = master_dict[subject_id][trial_num]['Trial_Total']["total_lap_time"]
        row_data[f'total_steering_acceleration_{trial_num}'] = master_dict[subject_id][trial_num]['Trial_Total']["total_steering_acceleration"]

        row_data[f'high_vis_lap_time_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["high_vis"]["lap_time"]
        row_data[f'high_vis_steering_acceleration_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["high_vis"]["steering_acceleration"]
        row_data[f'high_vis_mean_speed_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["high_vis"]["mean_speed"]
        row_data[f'high_vis_var_speed_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["high_vis"]["var_speed"]
        row_data[f'high_vis_mean_lane_dev_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["high_vis"]["mean_lane_dev"]
        row_data[f'high_vis_var_lane_dev_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["high_vis"]["var_lane_dev"]
        row_data[f'high_vis_mean_steering_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["high_vis"]["mean_steering"]
        row_data[f'high_vis_var_steering_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["high_vis"]["var_steering"]
        row_data[f'low_vis_mean_speed_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["low_vis"]["mean_speed"]
        row_data[f'low_vis_var_speed_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["low_vis"]["var_speed"]
        row_data[f'low_vis_mean_lane_dev_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["low_vis"]["mean_lane_dev"]
        row_data[f'low_vis_var_lane_dev_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["low_vis"]["var_lane_dev"]
        row_data[f'low_vis_mean_steering_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["low_vis"]["mean_steering"]
        row_data[f'low_vis_var_steering_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["low_vis"]["var_steering"]
        row_data[f'low_vis_lap_time_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["low_vis"]["lap_time"]
        row_data[f'low_vis_steering_acceleration_{trial_num}'] = master_dict[subject_id][trial_num]["Trial_Piece"]["low_vis"]["steering_acceleration"]

    # Append the row data to the master_df
    #master_df = master_df.append(row_data, ignore_index=True)
    master_df = pd.concat([master_df, pd.DataFrame([row_data])], ignore_index=True)
master_df.to_csv('C:/Users/graci/Dropbox/PAndA/Thesis Experiment 2/data/main_data/main_analysis_start.csv', index=False)
